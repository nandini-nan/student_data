# %%
import pandas as pd

# %%
data=pd.read_csv("student_data.csv")
data
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
data.columns
# Out:
# Index(['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
#        'assignment_score', 'midterm_score', 'final_exam_score',
#        'participation_score', 'internet_access', 'extra_classes',
#        'parent_education', 'sleep_hours', 'overall_score', 'grade'],
#       dtype='str')

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info
# Out:
# <bound method DataFrame.info of       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
data["gender"]
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996      Male
# 9997    Female
# 9998    Female
# 9999      Male
# Name: gender, Length: 10000, dtype: str

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data["gender"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=data[["overall_score","midterm_score","final_exam_score","assignment_score"]]
data
# Out:
#       overall_score  midterm_score  final_exam_score  assignment_score
# 0           52.3480          70.70             53.10             36.47
# 1           53.9485          27.92             87.17             34.25
# 2           82.0375          70.92             99.61             72.29
# 3           66.4110          31.73             88.85             97.63
# 4           65.6005          78.28             54.23             65.19
# ...             ...            ...               ...               ...
# 9995        55.6720          39.51             66.43             60.41
# 9996        66.0930          48.96             81.40             62.45
# 9997        73.0355          51.51             87.58             67.08
# 9998        71.5400          46.51             75.49             97.73
# 9999        84.1005          88.99             85.32             93.33
#
# [10000 rows x 4 columns]

# %%
data["overall_score"].value_counts().plot(kind="hist")
plt.show()

# %%
data["overall_score"].value_counts().plot(kind="bar")
plt.show()

# %%
data["overall_score"].value_counts().plot(kind="pie")
plt.show()

# %%
data["midterm_score"].value_counts().plot(kind="hist")
plt.show()

# %%
data["midterm_score"].value_counts().plot(kind="bar")
plt.show()

# %%
data["midterm_score"].value_counts().plot(kind="pie")
plt.show()

# %%
data["final_exam_score"].value_counts().plot(kind="hist")
plt.show()

# %%
data["final_exam_score"].value_counts().plot(kind="bar")
plt.show()

# %%
data["final_exam_score"].value_counts().plot(kind="pie")
plt.show()

# %%
data["assignment_score"].value_counts().plot(kind="hist")
plt.show()

# %%
data["assignment_score"].value_counts().plot(kind="bar")
plt.show()

# %%
data["assignment_score"].value_counts().plot(kind="pie")
plt.show()
